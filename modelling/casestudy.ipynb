# %% [markdown]
# # HDB Resale Price Prediction

# %% [markdown]
# ## Case Studies

# %% [markdown]
# ### Import Libraries

# %%
import random
random.seed(42)
import numpy as np
import pandas as pd
import pickle
import folium
from datetime import datetime
from math import radians
from sklearn.metrics.pairwise import haversine_distances

# Warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import Trained Random Forest Regressor

# %%
with open('price_model.pkl', 'rb') as f:
        price_model = pickle.load(f)

# %% [markdown]
# ### Import HDB Test Dataset

# %%
# Importing Data I
data_hdb_test_x = pd.read_csv('../dataset/hdb_test_x.csv')
data_hdb_test_x.index += 1
data_hdb_test_x
# Out:
#        floor_area_sqm   date_sold  lease_commence_date  remaining_lease  \
# 1               104.0  2023-01-01                 1983        59.416667
# 2               122.0  2022-01-01                 1996        73.666667
# 3               121.0  2011-08-01                 1996        84.000000
# 4               104.0  2018-05-01                 1998        79.166667
# 5                91.0  2014-08-01                 1980        65.000000
# ...               ...         ...                  ...              ...
# 63368           112.0  2021-09-01                 2016        93.833333
# 63369            74.0  2022-06-01                 1986        62.833333
# 63370           113.0  2022-12-01                 2016        92.416667
# 63371            61.0  2019-05-01                 1974        54.000000
# 63372           110.0  2019-04-01                 2008        88.333333
#
#        nearest_distance_to_mrt  healthcare_within_1km_count  \
# 1                        0.777                          4.0
# 2                        0.365                          7.0
# 3                        0.421                          1.0
# 4                        1.307                          4.0
# 5                        0.773                          9.0
# ...                        ...                          ...
# 63368                    0.267                          4.0
# 63369                    0.756                          5.0
# 63370                    1.260                          4.0
# 63371                    1.013                          1.0
# 63372                    0.226                          7.0
#
#        healthcare_within_1km_average_rating  healthcare_within_2km_count  \
# 1                                  2.925000                         10.0
# 2                                  2.471429                         74.0
# 3                                  4.800000                          6.0
# 4                                  2.050000                         22.0
# 5                                  2.444444                         18.0
# ...                                     ...                          ...
# 63368                              3.300000                         12.0
# 63369                              3.460000                          9.0
# 63370                              2.975000                         16.0
# 63371                              3.300000                         10.0
# 63372                              2.442857                         14.0
#
#        healthcare_within_2km_average_rating  recreational_within_1km_count  \
# 1                                  2.530000                            0.0
# 2                                  2.728378                            2.0
# 3                                  3.683333                            4.0
# 4                                  2.054545                            2.0
# 5                                  2.550000                            1.0
# ...                                     ...                            ...
# 63368                              2.791667                            4.0
# 63369                              2.555556                            1.0
# 63370                              2.306250                            2.0
# 63371                              2.350000                            2.0
# 63372                              2.507143                            1.0
#
#        ...  storey_range_26 TO 30  storey_range_31 TO 35  \
# 1      ...                  False                  False
# 2      ...                   True                  False
# 3      ...                  False                  False
# 4      ...                  False                  False
# 5      ...                  False                  False
# ...    ...                    ...                    ...
# 63368  ...                  False                  False
# 63369  ...                  False                  False
# 63370  ...                  False                  False
# 63371  ...                  False                  False
# 63372  ...                  False                  False
#
#        storey_range_36 TO 40  storey_range_41 TO 50  region_Central  \
# 1                      False                  False           False
# 2                      False                  False            True
# 3                      False                  False           False
# 4                      False                  False            True
# 5                      False                  False           False
# ...                      ...                    ...             ...
# 63368                  False                  False           False
# 63369                  False                  False           False
# 63370                  False                  False           False
# 63371                  False                  False           False
# 63372                  False                  False           False
#
#        region_City  region_East  region_North  region_South  region_West
# 1            False        False         False         False         True
# 2            False        False         False         False        False
# 3            False        False         False         False         True
# 4            False        False         False         False        False
# 5            False        False          True         False        False
# ...            ...          ...           ...           ...          ...
# 63368        False        False          True         False        False
# 63369        False        False         False         False         True
# 63370        False        False          True         False        False
# 63371        False        False         False         False         True
# 63372        False        False         False         False         True
#
# [63372 rows x 40 columns]

# %%
# Understanding Data I
data_hdb_test_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63372 entries, 1 to 63372
# Data columns (total 40 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   floor_area_sqm                          63372 non-null  float64
#  1   date_sold                               63372 non-null  object
#  2   lease_commence_date                     63372 non-null  int64
#  3   remaining_lease                         63372 non-null  float64
#  4   nearest_distance_to_mrt                 63372 non-null  float64
#  5   healthcare_within_1km_count             63372 non-null  float64
#  6   healthcare_within_1km_average_rating    63372 non-null  float64
#  7   healthcare_within_2km_count             63372 non-null  float64
#  8   healthcare_within_2km_average_rating    63372 non-null  float64
#  9   recreational_within_1km_count           63372 non-null  float64
#  10  recreational_within_1km_average_rating  63372 non-null  float64
#  11  recreational_within_2km_count           63372 non-null  float64
#  12  recreational_within_2km_average_rating  63372 non-null  float64
#  13  education_within_1km_count              63372 non-null  float64
#  14  education_within_1km_average_rating     63372 non-null  float64
#  15  education_within_2km_count              63372 non-null  float64
#  16  education_within_2km_average_rating     63372 non-null  float64
#  17  price_per_sqm                           63372 non-null  float64
#  18  flat_type_1 ROOM                        63372 non-null  bool
#  19  flat_type_2 ROOM                        63372 non-null  bool
#  20  flat_type_3 ROOM                        63372 non-null  bool
#  21  flat_type_4 ROOM                        63372 non-null  bool
#  22  flat_type_5 ROOM                        63372 non-null  bool
#  23  flat_type_EXECUTIVE                     63372 non-null  bool
#  24  flat_type_MULTI-GENERATION              63372 non-null  bool
#  25  storey_range_01 TO 05                   63372 non-null  bool
#  26  storey_range_06 TO 10                   63372 non-null  bool
#  27  storey_range_10 TO 15                   63372 non-null  bool
#  28  storey_range_16 TO 20                   63372 non-null  bool
#  29  storey_range_21 TO 25                   63372 non-null  bool
#  30  storey_range_26 TO 30                   63372 non-null  bool
#  31  storey_range_31 TO 35                   63372 non-null  bool
#  32  storey_range_36 TO 40                   63372 non-null  bool
#  33  storey_range_41 TO 50                   63372 non-null  bool
#  34  region_Central                          63372 non-null  bool
#  35  region_City                             63372 non-null  bool
#  36  region_East                             63372 non-null  bool
#  37  region_North                            63372 non-null  bool
#  38  region_South                            63372 non-null  bool
#  39  region_West                             63372 non-null  bool
# dtypes: bool(22), float64(16), int64(1), object(1)
# memory usage: 10.0+ MB

# %%
# Importing Data II
data_hdb_test_y = pd.read_csv('../dataset/hdb_test_y.csv')
data_hdb_test_y.index += 1
data_hdb_test_y
# Out:
#        resale_price
# 1          528000.0
# 2          932000.0
# 3          506000.0
# 4          580000.0
# 5          460000.0
# ...             ...
# 63368      669000.0
# 63369      345000.0
# 63370      670000.0
# 63371      190000.0
# 63372      448000.0
#
# [63372 rows x 1 columns]

# %%
# Understanding Data II
data_hdb_test_y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63372 entries, 1 to 63372
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   resale_price  63372 non-null  float64
# dtypes: float64(1)
# memory usage: 495.2 KB

# %% [markdown]
# ### Import HDB Merged Dataset

# %%
# Import Merged Dataset 
hdb_last15_merged = pd.read_csv('../dataset/hdb_last15_merged.csv')
hdb_last15_merged
# Out:
#                town flat_type         flat_model  floor_area_sqm  \
# 0         SEMBAWANG    5 ROOM  Premium Apartment           111.0
# 1         SEMBAWANG    5 ROOM  Premium Apartment           110.0
# 2         SEMBAWANG    5 ROOM  Premium Apartment           110.0
# 3         SEMBAWANG    4 ROOM  Premium Apartment            95.0
# 4         SEMBAWANG    4 ROOM  Premium Apartment            95.0
# ...             ...       ...                ...             ...
# 325965  BUKIT MERAH    5 ROOM           Improved           114.0
# 325966  BUKIT MERAH    5 ROOM           Improved           117.0
# 325967  BUKIT MERAH    5 ROOM           Improved           117.0
# 325968  BUKIT MERAH    5 ROOM           Improved           114.0
# 325969  BUKIT MERAH    5 ROOM           Improved           117.0
#
#         resale_price       month lease_commence_date storey_range block  \
# 0           362000.0  2009-07-01          2001-01-01     01 TO 05  357A
# 1           370000.0  2009-08-01          2001-01-01     06 TO 10  357A
# 2           403000.0  2010-01-01          2001-01-01     16 TO 20  357A
# 3           350000.0  2010-07-01          2001-01-01     01 TO 05  357A
# 4           399000.0  2010-07-01          2001-01-01     10 TO 15  357A
# ...              ...         ...                 ...          ...   ...
# 325965      921000.0  2022-10-01          1974-01-01     10 TO 15    87
# 325966      930000.0  2022-10-01          1974-01-01     01 TO 05    87
# 325967      978000.0  2022-12-01          1974-01-01     10 TO 15    87
# 325968      950000.0  2022-12-01          1974-01-01     21 TO 25    87
# 325969      888000.0  2023-01-01          1974-01-01     01 TO 05    87
#
#         remaining_lease  ... recreational_within_1km_count  \
# 0             91.000000  ...                           3.0
# 1             91.000000  ...                           3.0
# 2             90.000000  ...                           3.0
# 3             90.000000  ...                           3.0
# 4             90.000000  ...                           3.0
# ...                 ...  ...                           ...
# 325965        50.750000  ...                           7.0
# 325966        50.750000  ...                           7.0
# 325967        50.666667  ...                           7.0
# 325968        50.583333  ...                           7.0
# 325969        50.500000  ...                           7.0
#
#        recreational_within_1km_average_rating  recreational_within_2km_count  \
# 0                                    3.733333                            6.0
# 1                                    3.733333                            6.0
# 2                                    3.733333                            6.0
# 3                                    3.733333                            6.0
# 4                                    3.733333                            6.0
# ...                                       ...                            ...
# 325965                               4.057143                           78.0
# 325966                               4.057143                           78.0
# 325967                               4.057143                           78.0
# 325968                               4.057143                           78.0
# 325969                               4.057143                           78.0
#
#         recreational_within_2km_average_rating education_within_1km_count  \
# 0                                     3.916667                        4.0
# 1                                     3.916667                        4.0
# 2                                     3.916667                        4.0
# 3                                     3.916667                        4.0
# 4                                     3.916667                        4.0
# ...                                        ...                        ...
# 325965                                4.052564                        3.0
# 325966                                4.052564                        3.0
# 325967                                4.052564                        3.0
# 325968                                4.052564                        3.0
# 325969                                4.052564                        3.0
#
#         education_within_1km_average_rating education_within_2km_count  \
# 0                                     4.275                        8.0
# 1                                     4.275                        8.0
# 2                                     4.275                        8.0
# 3                                     4.275                        8.0
# 4                                     4.275                        8.0
# ...                                     ...                        ...
# 325965                                2.700                       25.0
# 325966                                2.700                       25.0
# 325967                                2.700                       25.0
# 325968                                2.700                       25.0
# 325969                                2.700                       25.0
#
#        education_within_2km_average_rating  postal_code  region
# 0                                    4.250     751357.0   North
# 1                                    4.250     751357.0   North
# 2                                    4.250     751357.0   North
# 3                                    4.250     751357.0   North
# 4                                    4.250     751357.0   North
# ...                                    ...          ...     ...
# 325965                               3.348     160087.0   South
# 325966                               3.348     160087.0   South
# 325967                               3.348     160087.0   South
# 325968                               3.348     160087.0   South
# 325969                               3.348     160087.0   South
#
# [325970 rows x 34 columns]

# %%
# Understanding Data 
hdb_last15_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325970 entries, 0 to 325969
# Data columns (total 34 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   town                                    325970 non-null  object
#  1   flat_type                               325970 non-null  object
#  2   flat_model                              325970 non-null  object
#  3   floor_area_sqm                          325970 non-null  float64
#  4   resale_price                            325970 non-null  float64
#  5   month                                   325970 non-null  object
#  6   lease_commence_date                     325970 non-null  object
#  7   storey_range                            325970 non-null  object
#  8   block                                   325970 non-null  object
#  9   remaining_lease                         325970 non-null  float64
#  10  address                                 325970 non-null  object
#  11  full_address                            325970 non-null  object
#  12  lat                                     325970 non-null  float64
#  13  long                                    325970 non-null  float64
#  14  nearest_mrt                             325970 non-null  object
#  15  nearest_distance_to_mrt                 325970 non-null  float64
#  16  flat_category                           325970 non-null  object
#  17  street_name                             325970 non-null  object
#  18  avg_long                                325970 non-null  float64
#  19  avg_lat                                 325970 non-null  float64
#  20  healthcare_within_1km_count             325970 non-null  float64
#  21  healthcare_within_1km_average_rating    325970 non-null  float64
#  22  healthcare_within_2km_count             325970 non-null  float64
#  23  healthcare_within_2km_average_rating    325970 non-null  float64
#  24  recreational_within_1km_count           325970 non-null  float64
#  25  recreational_within_1km_average_rating  325970 non-null  float64
#  26  recreational_within_2km_count           325970 non-null  float64
#  27  recreational_within_2km_average_rating  325970 non-null  float64
#  28  education_within_1km_count              325970 non-null  float64
#  29  education_within_1km_average_rating     325970 non-null  float64
#  30  education_within_2km_count              325970 non-null  float64
#  31  education_within_2km_average_rating     325970 non-null  float64
#  32  postal_code                             325522 non-null  float64
#  33  region                                  325970 non-null  object
# dtypes: float64(21), object(13)
# memory usage: 84.6+ MB

# %% [markdown]
# ### Import POI Dataset

# %%
# Importing Data
data_poi_raw = pd.read_csv('../dataset/points_of_interest.csv')
data_poi_raw
# Out:
#       Unnamed: 0                     place_id                         name  \
# 0              0  ChIJ01fgzLUe2jERxlhvImcbZ7g                Quayside Isle
# 1              1  ChIJ1S4qfY8Q2jERgb68gskzUbo            Sime Darby Centre
# 2              2  ChIJ1ZAIkrwZ2jERxtZGC1JnrHM                         PoMo
# 3              3  ChIJ1ZYJOiAZ2jER1mvQqHstQII               LR boulangerie
# 4              4  ChIJ2Y1DYBI92jERlFUKKSznJrY                 Tampines Hub
# ...          ...                          ...                          ...
# 8667        8667  ChIJic0FbG4T2jERlg__g9KNSUU  Old Chang Kee (Head Office)
# 8668        8668  ChIJ7cjSMX0T2jERGYqGQog7A2E    Old Chang Kee @ Sun Plaza
# 8669        8669  ChIJxXwRE24T2jERDGyVjkkHTTs           Old Chang Kee Bldg
# 8670        8670  ChIJmQOMh1AT2jERs_1tteD7eTg      Old Chang Kee Coldstore
# 8671        8671  ChIJkYvJbm4T2jERIfS4wTtaBZg    Ten & Han Trading Pte Ltd
#
#            lat         lng  rating  user_ratings_total  price_level  \
# 0     1.247681  103.842072     4.3               568.0          NaN
# 1     1.336644  103.783597     3.7               437.0          NaN
# 2     1.300192  103.849220     3.8              1285.0          NaN
# 3     1.293178  103.827194     4.3                12.0          NaN
# 4     1.353108  103.940361     4.6               227.0          NaN
# ...        ...         ...     ...                 ...          ...
# 8667  1.450192  103.805305     4.3                25.0          1.0
# 8668  1.448144  103.819983     3.4                10.0          1.0
# 8669  1.449830  103.805229     4.0                 2.0          NaN
# 8670  1.468055  103.812869     0.0                 0.0          NaN
# 8671  1.450047  103.805526     3.0                 1.0          NaN
#
#                                       formatted_address  global_code  ...  \
# 0                        31 Ocean Way, Singapore 098375  6PH56RXR+3R  ...
# 1                      896 Dunearn Rd, Singapore 589472  6PH58QPM+MC  ...
# 2                        1 Selegie Rd, Singapore 188306  6PH58R2X+3M  ...
# 3     491 River Valley Rd, #01-02 valley point shopp...  6PH57RVG+7V  ...
# 4                     1 Tampines Walk, Singapore 528523  6PH59W3R+64  ...
# ...                                                 ...          ...  ...
# 8667                     2 Woodlands Terrace, Singapore  6PH5FR24+34  ...
# 8668       30 Sembawang Dr, #B1-44 Sun Plaza, Singapore  6PH5CRX9+7X  ...
# 8669                                          Singapore  6PH5CRX4+W3  ...
# 8670                           20 Senoko Way, Singapore  6PH5FR97+64  ...
# 8671                     2 Woodlands Terrace, Singapore  6PH5FR24+26  ...
#
#      train_station natural_feature subpremise  SUBZONE_NO          SUBZONE_N  \
# 0            False           False      False         1.0            SENTOSA
# 1            False           False      False         2.0         SWISS CLUB
# 2            False           False      False         8.0            SELEGIE
# 3            False           False      False         2.0         CHATSWORTH
# 4            False           False      False         3.0      TAMPINES WEST
# ...            ...             ...        ...         ...                ...
# 8667         False           False      False         9.0       SENOKO SOUTH
# 8668         False           False      False         3.0  SEMBAWANG CENTRAL
# 8669         False           False      False         9.0       SENOKO SOUTH
# 8670         False           False      False         8.0       SENOKO NORTH
# 8671         False           False      False         9.0       SENOKO SOUTH
#
#       SUBZONE_C        PLN_AREA_N  PLN_AREA_C        REGION_N  REGION_C
# 0        SISZ01  SOUTHERN ISLANDS          SI  CENTRAL REGION        CR
# 1        BTSZ02       BUKIT TIMAH          BT  CENTRAL REGION        CR
# 2        RCSZ08            ROCHOR          RC  CENTRAL REGION        CR
# 3        TNSZ02           TANGLIN          TN  CENTRAL REGION        CR
# 4        TMSZ03          TAMPINES          TM     EAST REGION        ER
# ...         ...               ...         ...             ...       ...
# 8667     SBSZ09         SEMBAWANG          SB    NORTH REGION        NR
# 8668     SBSZ03         SEMBAWANG          SB    NORTH REGION        NR
# 8669     SBSZ09         SEMBAWANG          SB    NORTH REGION        NR
# 8670     SBSZ08         SEMBAWANG          SB    NORTH REGION        NR
# 8671     SBSZ09         SEMBAWANG          SB    NORTH REGION        NR
#
# [8672 rows x 125 columns]

# %% [markdown]
# ## Mini Case Study: HDB Flat in [ Location ]

# %% [markdown]
# ### Selection of Specific Flat

# %%
# Placeholder Flat
random_index = random.choice(data_hdb_test_x.index)
print(random_index)

data_hdb_selected_x = data_hdb_test_x[data_hdb_test_x.index == random_index]
data_hdb_selected_y = data_hdb_test_y[data_hdb_test_y.index == random_index]
# Out:
# 14629

# %%
data_hdb_selected_x
# Out:
#        floor_area_sqm   date_sold  lease_commence_date  remaining_lease  \
# 14629            87.0  2021-12-01                 2016            93.75
#
#        nearest_distance_to_mrt  healthcare_within_1km_count  \
# 14629                     0.43                          4.0
#
#        healthcare_within_1km_average_rating  healthcare_within_2km_count  \
# 14629                                 3.475                         49.0
#
#        healthcare_within_2km_average_rating  recreational_within_1km_count  \
# 14629                              2.581633                            3.0
#
#        ...  storey_range_26 TO 30  storey_range_31 TO 35  \
# 14629  ...                  False                  False
#
#        storey_range_36 TO 40  storey_range_41 TO 50  region_Central  \
# 14629                  False                  False           False
#
#        region_City  region_East  region_North  region_South  region_West
# 14629        False        False         False          True        False
#
# [1 rows x 40 columns]

# %%
data_hdb_selected_y
# Out:
#        resale_price
# 14629      855000.0

# %%
# Retrieve from Selected X Dataset
actual_price = data_hdb_selected_y.iloc[0, 0]
actual_fas =  data_hdb_selected_x.iloc[0, 0]
actual_month = data_hdb_selected_x.iloc[0, 1]

# Retrieve from Merged Dataset
hdb_last15_merged_selected = hdb_last15_merged[(hdb_last15_merged.resale_price == actual_price) & 
                                               (hdb_last15_merged.floor_area_sqm == actual_fas) &
                                               (hdb_last15_merged.month == actual_month)]
hdb_last15_merged_selected
# Out:
#               town flat_type         flat_model  floor_area_sqm  resale_price  \
# 101195  QUEENSTOWN    4 ROOM  Premium Apartment            87.0      855000.0
#
#              month lease_commence_date storey_range block  remaining_lease  \
# 101195  2021-12-01          2016-01-01     16 TO 20    87            93.75
#
#         ... recreational_within_1km_count  \
# 101195  ...                           3.0
#
#        recreational_within_1km_average_rating  recreational_within_2km_count  \
# 101195                                    4.2                           12.0
#
#         recreational_within_2km_average_rating education_within_1km_count  \
# 101195                                4.041667                        4.0
#
#         education_within_1km_average_rating education_within_2km_count  \
# 101195                                 3.85                       12.0
#
#        education_within_2km_average_rating  postal_code  region
# 101195                            3.991667     141087.0   South
#
# [1 rows x 34 columns]

# %%
latitude = hdb_last15_merged_selected.lat
longitude = hdb_last15_merged_selected.long

# %% [markdown]
# ### Model Prediction

# %%
# Predictor Columns
predictor_cols = ['floor_area_sqm', 'remaining_lease', 'nearest_distance_to_mrt', 
                  'healthcare_within_1km_count', 'healthcare_within_1km_average_rating',
                  'healthcare_within_2km_count', 'healthcare_within_2km_average_rating', 
                  'recreational_within_1km_count', 'recreational_within_1km_average_rating', 
                  'recreational_within_2km_count', 'education_within_1km_count',
                  'education_within_1km_average_rating', 'education_within_2km_count',
                  'price_per_sqm', 'flat_type_3 ROOM', 'flat_type_4 ROOM',
                  'flat_type_5 ROOM', 'flat_type_EXECUTIVE', 'storey_range_01 TO 05',
                  'storey_range_06 TO 10', 'storey_range_10 TO 15', 'region_Central',
                  'region_East', 'region_North', 'region_South', 'region_West']

predictors = data_hdb_selected_x[predictor_cols]

# %%
# Predicted Value
predicted_price = price_model.predict(predictors)[0]
print("Predicted Resale Price:", predicted_price)

# Actual Value
print("Actual Resale Price:", actual_price)
# Out:
# Predicted Resale Price: 854790.0
# Actual Resale Price: 855000.0

# %% [markdown]
# From the Model's prediction, we can see that the predicted price differs from the actual price by only $210.

# %% [markdown]
# ### POIs Around HDB Flat

# %%
## Use Cells Here

# %% [markdown]
# ### HDB Flat Map

# %%
hdb_map = folium.Map(location = [latitude, longitude], zoom_start = 16)

# HDB Flat
popup_content_hdb = f"Predicted Price: {predicted_price}<br>Actual Price: {actual_price}"
folium.Marker(location = [latitude, longitude], 
              icon = folium.Icon(color = 'red'), 
              popup = folium.Popup(popup_content_hdb, max_width=500)).add_to(hdb_map)


# POIs Near HDB Flat
## Write Here 


hdb_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_135b8ec3ba014339018d47416dddc0c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_135b8ec3ba014339018d47416dddc0c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_135b8ec3ba014339018d47416dddc0c3 = L.map(
#                 &quot;map_135b8ec3ba014339018d47416dddc0c3&quot;,
#                 {
#                     center: [1.2957304268451, 103.809759937443],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b38b1cb6742e17c7338465e980e66ac6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b38b1cb6742e17c7338465e980e66ac6.addTo(map_135b8ec3ba014339018d47416dddc0c3);
#
#
#             var marker_bd915611e79684853649e728f4fbd2e9 = L.marker(
#                 [1.2957304268451, 103.809759937443],
#                 {}
#             ).addTo(map_135b8ec3ba014339018d47416dddc0c3);
#
#
#             var icon_dc658b6794b402e76fb18ee264a8766c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bd915611e79684853649e728f4fbd2e9.setIcon(icon_dc658b6794b402e76fb18ee264a8766c);
#
#
#         var popup_14bfd2df91cb9b99e8d3f774fa82854b = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_8223e941b8c2e90390220e61b294356e = $(`&lt;div id=&quot;html_8223e941b8c2e90390220e61b294356e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Predicted Price: 854790.0&lt;br&gt;Actual Price: 855000.0&lt;/div&gt;`)[0];
#                 popup_14bfd2df91cb9b99e8d3f774fa82854b.setContent(html_8223e941b8c2e90390220e61b294356e);
#
#
#
#         marker_bd915611e79684853649e728f4fbd2e9.bindPopup(popup_14bfd2df91cb9b99e8d3f774fa82854b)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Save Map

# %%
# Save the map to an HTML file
hdb_map.save('hdb_map.html')
