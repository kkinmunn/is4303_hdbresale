# %% [markdown]
# # HDB Resale Price Prediction

# %% [markdown]
# ## Case Studies

# %% [markdown]
# ### Import Libraries

# %%
import random
random.seed(42)
import numpy as np
import pandas as pd
import pickle
import folium
from datetime import datetime
from math import radians
from sklearn.metrics.pairwise import haversine_distances

# Warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import Trained Random Forest Regressor

# %%
with open('price_model.pkl', 'rb') as f:
        price_model = pickle.load(f)

# %% [markdown]
# ### Import HDB Test Dataset

# %%
# Importing Data I
data_hdb_test_x = pd.read_csv('../dataset/hdb_test_x.csv')
data_hdb_test_x.index += 1
data_hdb_test_x
# Out:
#        floor_area_sqm   date_sold  lease_commence_date  remaining_lease  \
# 1               104.0  2023-01-01                 1983        59.416667
# 2               122.0  2022-01-01                 1996        73.666667
# 3               121.0  2011-08-01                 1996        84.000000
# 4               104.0  2018-05-01                 1998        79.166667
# 5                91.0  2014-08-01                 1980        65.000000
# ...               ...         ...                  ...              ...
# 63368           112.0  2021-09-01                 2016        93.833333
# 63369            74.0  2022-06-01                 1986        62.833333
# 63370           113.0  2022-12-01                 2016        92.416667
# 63371            61.0  2019-05-01                 1974        54.000000
# 63372           110.0  2019-04-01                 2008        88.333333
#
#        nearest_distance_to_mrt  healthcare_within_1km_count  \
# 1                        0.777                          4.0
# 2                        0.365                          7.0
# 3                        0.421                          1.0
# 4                        1.307                          4.0
# 5                        0.773                          9.0
# ...                        ...                          ...
# 63368                    0.267                          4.0
# 63369                    0.756                          5.0
# 63370                    1.260                          4.0
# 63371                    1.013                          1.0
# 63372                    0.226                          7.0
#
#        healthcare_within_1km_average_rating  healthcare_within_2km_count  \
# 1                                  2.925000                         10.0
# 2                                  2.471429                         74.0
# 3                                  4.800000                          6.0
# 4                                  2.050000                         22.0
# 5                                  2.444444                         18.0
# ...                                     ...                          ...
# 63368                              3.300000                         12.0
# 63369                              3.460000                          9.0
# 63370                              2.975000                         16.0
# 63371                              3.300000                         10.0
# 63372                              2.442857                         14.0
#
#        healthcare_within_2km_average_rating  recreational_within_1km_count  \
# 1                                  2.530000                            0.0
# 2                                  2.728378                            2.0
# 3                                  3.683333                            4.0
# 4                                  2.054545                            2.0
# 5                                  2.550000                            1.0
# ...                                     ...                            ...
# 63368                              2.791667                            4.0
# 63369                              2.555556                            1.0
# 63370                              2.306250                            2.0
# 63371                              2.350000                            2.0
# 63372                              2.507143                            1.0
#
#        ...  storey_range_26 TO 30  storey_range_31 TO 35  \
# 1      ...                  False                  False
# 2      ...                   True                  False
# 3      ...                  False                  False
# 4      ...                  False                  False
# 5      ...                  False                  False
# ...    ...                    ...                    ...
# 63368  ...                  False                  False
# 63369  ...                  False                  False
# 63370  ...                  False                  False
# 63371  ...                  False                  False
# 63372  ...                  False                  False
#
#        storey_range_36 TO 40  storey_range_41 TO 50  region_Central  \
# 1                      False                  False           False
# 2                      False                  False            True
# 3                      False                  False           False
# 4                      False                  False            True
# 5                      False                  False           False
# ...                      ...                    ...             ...
# 63368                  False                  False           False
# 63369                  False                  False           False
# 63370                  False                  False           False
# 63371                  False                  False           False
# 63372                  False                  False           False
#
#        region_City  region_East  region_North  region_South  region_West
# 1            False        False         False         False         True
# 2            False        False         False         False        False
# 3            False        False         False         False         True
# 4            False        False         False         False        False
# 5            False        False          True         False        False
# ...            ...          ...           ...           ...          ...
# 63368        False        False          True         False        False
# 63369        False        False         False         False         True
# 63370        False        False          True         False        False
# 63371        False        False         False         False         True
# 63372        False        False         False         False         True
#
# [63372 rows x 40 columns]

# %%
# Understanding Data I
data_hdb_test_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63372 entries, 1 to 63372
# Data columns (total 40 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   floor_area_sqm                          63372 non-null  float64
#  1   date_sold                               63372 non-null  object
#  2   lease_commence_date                     63372 non-null  int64
#  3   remaining_lease                         63372 non-null  float64
#  4   nearest_distance_to_mrt                 63372 non-null  float64
#  5   healthcare_within_1km_count             63372 non-null  float64
#  6   healthcare_within_1km_average_rating    63372 non-null  float64
#  7   healthcare_within_2km_count             63372 non-null  float64
#  8   healthcare_within_2km_average_rating    63372 non-null  float64
#  9   recreational_within_1km_count           63372 non-null  float64
#  10  recreational_within_1km_average_rating  63372 non-null  float64
#  11  recreational_within_2km_count           63372 non-null  float64
#  12  recreational_within_2km_average_rating  63372 non-null  float64
#  13  education_within_1km_count              63372 non-null  float64
#  14  education_within_1km_average_rating     63372 non-null  float64
#  15  education_within_2km_count              63372 non-null  float64
#  16  education_within_2km_average_rating     63372 non-null  float64
#  17  price_per_sqm                           63372 non-null  float64
#  18  flat_type_1 ROOM                        63372 non-null  bool
#  19  flat_type_2 ROOM                        63372 non-null  bool
#  20  flat_type_3 ROOM                        63372 non-null  bool
#  21  flat_type_4 ROOM                        63372 non-null  bool
#  22  flat_type_5 ROOM                        63372 non-null  bool
#  23  flat_type_EXECUTIVE                     63372 non-null  bool
#  24  flat_type_MULTI-GENERATION              63372 non-null  bool
#  25  storey_range_01 TO 05                   63372 non-null  bool
#  26  storey_range_06 TO 10                   63372 non-null  bool
#  27  storey_range_10 TO 15                   63372 non-null  bool
#  28  storey_range_16 TO 20                   63372 non-null  bool
#  29  storey_range_21 TO 25                   63372 non-null  bool
#  30  storey_range_26 TO 30                   63372 non-null  bool
#  31  storey_range_31 TO 35                   63372 non-null  bool
#  32  storey_range_36 TO 40                   63372 non-null  bool
#  33  storey_range_41 TO 50                   63372 non-null  bool
#  34  region_Central                          63372 non-null  bool
#  35  region_City                             63372 non-null  bool
#  36  region_East                             63372 non-null  bool
#  37  region_North                            63372 non-null  bool
#  38  region_South                            63372 non-null  bool
#  39  region_West                             63372 non-null  bool
# dtypes: bool(22), float64(16), int64(1), object(1)
# memory usage: 10.0+ MB

# %%
# Importing Data II
data_hdb_test_y = pd.read_csv('../dataset/hdb_test_y.csv')
data_hdb_test_y.index += 1
data_hdb_test_y
# Out:
#        resale_price
# 1          528000.0
# 2          932000.0
# 3          506000.0
# 4          580000.0
# 5          460000.0
# ...             ...
# 63368      669000.0
# 63369      345000.0
# 63370      670000.0
# 63371      190000.0
# 63372      448000.0
#
# [63372 rows x 1 columns]

# %%
# Understanding Data II
data_hdb_test_y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63372 entries, 1 to 63372
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   resale_price  63372 non-null  float64
# dtypes: float64(1)
# memory usage: 495.2 KB

# %% [markdown]
# ### Import HDB Merged Dataset

# %%
# Import Cleaned Dataset 
# Replaced merged with cleaned as merged includes flats with remaining lease > 95 years
hdb_last15_cleaned = pd.read_csv('../dataset/hdb_last15_cleaned.csv')
hdb_last15_cleaned
# Out:
#                town flat_type         flat_model  floor_area_sqm  \
# 0         SEMBAWANG    5 ROOM  Premium Apartment           111.0
# 1         SEMBAWANG    5 ROOM  Premium Apartment           110.0
# 2         SEMBAWANG    5 ROOM  Premium Apartment           110.0
# 3         SEMBAWANG    4 ROOM  Premium Apartment            95.0
# 4         SEMBAWANG    4 ROOM  Premium Apartment            95.0
# ...             ...       ...                ...             ...
# 316853  BUKIT MERAH    5 ROOM           Improved           114.0
# 316854  BUKIT MERAH    5 ROOM           Improved           117.0
# 316855  BUKIT MERAH    5 ROOM           Improved           117.0
# 316856  BUKIT MERAH    5 ROOM           Improved           114.0
# 316857  BUKIT MERAH    5 ROOM           Improved           117.0
#
#         resale_price       month  lease_commence_date storey_range block  \
# 0           362000.0  2009-07-01                 2001     01 TO 05  357A
# 1           370000.0  2009-08-01                 2001     06 TO 10  357A
# 2           403000.0  2010-01-01                 2001     16 TO 20  357A
# 3           350000.0  2010-07-01                 2001     01 TO 05  357A
# 4           399000.0  2010-07-01                 2001     10 TO 15  357A
# ...              ...         ...                  ...          ...   ...
# 316853      921000.0  2022-10-01                 1974     10 TO 15    87
# 316854      930000.0  2022-10-01                 1974     01 TO 05    87
# 316855      978000.0  2022-12-01                 1974     10 TO 15    87
# 316856      950000.0  2022-12-01                 1974     21 TO 25    87
# 316857      888000.0  2023-01-01                 1974     01 TO 05    87
#
#         remaining_lease  ... recreational_within_1km_average_rating  \
# 0             91.000000  ...                               3.733333
# 1             91.000000  ...                               3.733333
# 2             90.000000  ...                               3.733333
# 3             90.000000  ...                               3.733333
# 4             90.000000  ...                               3.733333
# ...                 ...  ...                                    ...
# 316853        50.750000  ...                               4.057143
# 316854        50.750000  ...                               4.057143
# 316855        50.666667  ...                               4.057143
# 316856        50.583333  ...                               4.057143
# 316857        50.500000  ...                               4.057143
#
#        recreational_within_2km_count  recreational_within_2km_average_rating  \
# 0                                6.0                                3.916667
# 1                                6.0                                3.916667
# 2                                6.0                                3.916667
# 3                                6.0                                3.916667
# 4                                6.0                                3.916667
# ...                              ...                                     ...
# 316853                          78.0                                4.052564
# 316854                          78.0                                4.052564
# 316855                          78.0                                4.052564
# 316856                          78.0                                4.052564
# 316857                          78.0                                4.052564
#
#         education_within_1km_count education_within_1km_average_rating  \
# 0                              4.0                               4.275
# 1                              4.0                               4.275
# 2                              4.0                               4.275
# 3                              4.0                               4.275
# 4                              4.0                               4.275
# ...                            ...                                 ...
# 316853                         3.0                               2.700
# 316854                         3.0                               2.700
# 316855                         3.0                               2.700
# 316856                         3.0                               2.700
# 316857                         3.0                               2.700
#
#         education_within_2km_count education_within_2km_average_rating  \
# 0                              8.0                               4.250
# 1                              8.0                               4.250
# 2                              8.0                               4.250
# 3                              8.0                               4.250
# 4                              8.0                               4.250
# ...                            ...                                 ...
# 316853                        25.0                               3.348
# 316854                        25.0                               3.348
# 316855                        25.0                               3.348
# 316856                        25.0                               3.348
# 316857                        25.0                               3.348
#
#        postal_code  region  price_per_sqm
# 0         751357.0   North    3261.261261
# 1         751357.0   North    3363.636364
# 2         751357.0   North    3663.636364
# 3         751357.0   North    3684.210526
# 4         751357.0   North    4200.000000
# ...            ...     ...            ...
# 316853    160087.0   South    8078.947368
# 316854    160087.0   South    7948.717949
# 316855    160087.0   South    8358.974359
# 316856    160087.0   South    8333.333333
# 316857    160087.0   South    7589.743590
#
# [316858 rows x 35 columns]

# %%
# Understanding Data 
hdb_last15_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316858 entries, 0 to 316857
# Data columns (total 35 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   town                                    316858 non-null  object
#  1   flat_type                               316858 non-null  object
#  2   flat_model                              316858 non-null  object
#  3   floor_area_sqm                          316858 non-null  float64
#  4   resale_price                            316858 non-null  float64
#  5   month                                   316858 non-null  object
#  6   lease_commence_date                     316858 non-null  int64
#  7   storey_range                            316858 non-null  object
#  8   block                                   316858 non-null  object
#  9   remaining_lease                         316858 non-null  float64
#  10  address                                 316858 non-null  object
#  11  full_address                            316858 non-null  object
#  12  lat                                     316858 non-null  float64
#  13  long                                    316858 non-null  float64
#  14  nearest_mrt                             316858 non-null  object
#  15  nearest_distance_to_mrt                 316858 non-null  float64
#  16  flat_category                           316858 non-null  object
#  17  street_name                             316858 non-null  object
#  18  avg_long                                316858 non-null  float64
#  19  avg_lat                                 316858 non-null  float64
#  20  healthcare_within_1km_count             316858 non-null  float64
#  21  healthcare_within_1km_average_rating    316858 non-null  float64
#  22  healthcare_within_2km_count             316858 non-null  float64
#  23  healthcare_within_2km_average_rating    316858 non-null  float64
#  24  recreational_within_1km_count           316858 non-null  float64
#  25  recreational_within_1km_average_rating  316858 non-null  float64
#  26  recreational_within_2km_count           316858 non-null  float64
#  27  recreational_within_2km_average_rating  316858 non-null  float64
#  28  education_within_1km_count              316858 non-null  float64
#  29  education_within_1km_average_rating     316858 non-null  float64
#  30  education_within_2km_count              316858 non-null  float64
#  31  education_within_2km_average_rating     316858 non-null  float64
#  32  postal_code                             316410 non-null  float64
#  33  region                                  316858 non-null  object
#  34  price_per_sqm                           316858 non-null  float64
# dtypes: float64(22), int64(1), object(12)
# memory usage: 84.6+ MB

# %% [markdown]
# ### Import POI Dataset

# %%
# Importing Data
data_poi_raw = pd.read_csv('../dataset/points_of_interest.csv')
data_poi_raw

# %% [markdown]
# ## Mini Case Study: HDB Flat in Tampines

# %% [markdown]
# The objective of this case study is to provide a visualisation of whether and how a flat's features can contribute to its resale price. More specifically, we hope to present a flat in its geographical context such as its location, and the amenities around it to and uncover the impact that its geographical context can have on its resale price.

# %% [markdown]
# ### Selection of Specific Flat

# %% [markdown]
# In alignment with the case study's objective, HDB flats that exhibit great performance in terms of POI-related data will be identified. Thus, we calculate the 75th percentile of each POI-related measure below to serve as a filter for potential target flats.

# %%
# Finding the 75th Percentile for POI Data
q3_healthcare_1km_count = np.percentile(data_hdb_test_x['healthcare_within_1km_count'], 75)
q3_healthcare_1km_rating = np.percentile(data_hdb_test_x['healthcare_within_1km_average_rating'], 75)

q3_healthcare_2km_count = np.percentile(data_hdb_test_x['healthcare_within_2km_count'], 75)
q3_healthcare_2km_rating = np.percentile(data_hdb_test_x['healthcare_within_2km_average_rating'], 75)

q3_education_1km_count = np.percentile(data_hdb_test_x['education_within_1km_count'], 75)
q3_education_1km_rating = np.percentile(data_hdb_test_x['education_within_1km_average_rating'], 75)

q3_education_2km_count = np.percentile(data_hdb_test_x['education_within_2km_count'], 75)
q3_education_2km_rating = np.percentile(data_hdb_test_x['education_within_2km_average_rating'], 75)

q3_recreational_1km_count = np.percentile(data_hdb_test_x['recreational_within_1km_count'], 75)
q3_recreational_1km_rating = np.percentile(data_hdb_test_x['recreational_within_1km_average_rating'], 75)

q3_recreational_2km_count = np.percentile(data_hdb_test_x['recreational_within_2km_count'], 75)
q3_recreational_2km_rating = np.percentile(data_hdb_test_x['recreational_within_2km_average_rating'], 75)

print("3rd Quartile for Healthcare POI Count (1km): ", q3_healthcare_1km_count)
print("3rd Quartile for Healthcare POI Avg Rating (1km): ", q3_healthcare_1km_rating)

print("3rd Quartile for Healthcare POI Count (2km): ", q3_healthcare_2km_count)
print("3rd Quartile for Healthcare POI Avg Rating (2km): ", q3_healthcare_2km_rating)

print("3rd Quartile for Education POI Count (1km): ", q3_education_1km_count)
print("3rd Quartile for Education POI Avg Rating (1km): ", q3_education_1km_rating)

print("3rd Quartile for Education POI Count (2km): ", q3_education_2km_count)
print("3rd Quartile for Education POI Avg Rating (2km): ", q3_education_2km_rating)

print("3rd Quartile for Recreational POI Count (1km): ", q3_recreational_1km_count)
print("3rd Quartile for Recreational POI Avg Rating (1km): ", q3_recreational_1km_rating)

print("3rd Quartile for Recreational POI Count (2km): ", q3_recreational_2km_count)
print("3rd Quartile for Recreational POI Avg Rating (2km): ", q3_recreational_2km_rating)
# Out:
# 3rd Quartile for Healthcare POI Count (1km):  8.0
# 3rd Quartile for Healthcare POI Avg Rating (1km):  3.233333333333333
# 3rd Quartile for Healthcare POI Count (2km):  22.0
# 3rd Quartile for Healthcare POI Avg Rating (2km):  2.8
# 3rd Quartile for Education POI Count (1km):  6.0
# 3rd Quartile for Education POI Avg Rating (1km):  4.266666666666667
# 3rd Quartile for Education POI Count (2km):  17.0
# 3rd Quartile for Education POI Avg Rating (2km):  4.205263157894737
# 3rd Quartile for Recreational POI Count (1km):  5.0
# 3rd Quartile for Recreational POI Avg Rating (1km):  4.15
# 3rd Quartile for Recreational POI Count (2km):  13.0
# 3rd Quartile for Recreational POI Avg Rating (2km):  4.136363636363637

# %% [markdown]
# Upon trial and error, it is observed that the most encompassing combination of POI-measures for which there exists HDB flats above the 75th percentile across all measures includes:
# 1. Average rating of healthcare POIs within 2km
# 2. Average rating of healthcare POIs within 1km
# 3. Average rating of education POIs within 2km
# 4. Average rating of education POIs within 1km
# 5. Number of recreational POIs within 2km
# 6. Average rating of recreation POIs within 2km

# %%
# Finding the HDB Flats with the best POI statistics
# The maximum number/combination of POI-related attributes for which there exists flats with POI values above the 75th percentile has been used
potential_cases1_x = data_hdb_test_x[(data_hdb_test_x.healthcare_within_2km_average_rating > q3_healthcare_2km_rating) &
                                    (data_hdb_test_x.healthcare_within_1km_average_rating > q3_healthcare_1km_rating) &
                                    (data_hdb_test_x.education_within_2km_average_rating > q3_education_2km_rating) &
                                    (data_hdb_test_x.education_within_1km_average_rating > q3_education_1km_rating) &
                                    (data_hdb_test_x.recreational_within_2km_count > q3_recreational_2km_count) &
                                    (data_hdb_test_x.recreational_within_2km_average_rating > q3_recreational_2km_rating)]
                
potential_cases1_x
# Out:
#        floor_area_sqm   date_sold  lease_commence_date  remaining_lease  \
# 1589            127.0  2020-01-01                 1994        73.833333
# 2377            124.0  2019-08-01                 1994        74.333333
# 8411            126.0  2011-06-01                 1994        82.000000
# 9872            105.0  2018-04-01                 1994        74.916667
# 14003           137.0  2011-09-01                 1994        82.000000
# 14528           121.0  2021-08-01                 1994        72.333333
# 19148           127.0  2017-08-01                 1994        76.250000
# 21785           137.0  2013-03-01                 1994        80.000000
# 22966           104.0  2015-10-01                 1994        78.000000
# 23368           121.0  2015-04-01                 1994        78.000000
# 23785           107.0  2015-09-01                 1994        78.000000
# 28680           105.0  2009-03-01                 1994        84.000000
# 29387           128.0  2012-01-01                 1994        81.000000
# 32252           107.0  2019-05-01                 1994        73.833333
# 37419           124.0  2012-10-01                 1994        81.000000
# 37439           137.0  2018-07-01                 1994        74.666667
# 41908           108.0  2022-01-01                 1994        71.916667
# 43487           104.0  2016-12-01                 1994        76.000000
# 43611           108.0  2009-04-01                 1994        84.000000
# 43737           105.0  2022-10-01                 1994        70.500000
# 45873           128.0  2012-12-01                 1994        81.000000
# 49015           105.0  2012-04-01                 1994        81.000000
# 53615           107.0  2010-07-01                 1994        83.000000
# 54575           105.0  2017-05-01                 1994        75.833333
# 61437           126.0  2023-01-01                 1994        70.333333
#
#        nearest_distance_to_mrt  healthcare_within_1km_count  \
# 1589                     0.194                          4.0
# 2377                     0.208                          4.0
# 8411                     0.335                          4.0
# 9872                     0.374                          4.0
# 14003                    0.374                          4.0
# 14528                    0.161                          4.0
# 19148                    0.194                          4.0
# 21785                    0.331                          4.0
# 22966                    0.194                          4.0
# 23368                    0.335                          4.0
# 23785                    0.161                          4.0
# 28680                    0.161                          4.0
# 29387                    0.208                          4.0
# 32252                    0.335                          4.0
# 37419                    0.331                          4.0
# 37439                    0.374                          4.0
# 41908                    0.208                          4.0
# 43487                    0.374                          4.0
# 43611                    0.208                          4.0
# 43737                    0.331                          4.0
# 45873                    0.374                          4.0
# 49015                    0.331                          4.0
# 53615                    0.161                          4.0
# 54575                    0.331                          4.0
# 61437                    0.335                          4.0
#
#        healthcare_within_1km_average_rating  healthcare_within_2km_count  \
# 1589                                  4.075                         18.0
# 2377                                  4.075                         18.0
# 8411                                  4.075                         18.0
# 9872                                  4.075                         18.0
# 14003                                 4.075                         18.0
# 14528                                 4.075                         18.0
# 19148                                 4.075                         18.0
# 21785                                 4.075                         18.0
# 22966                                 4.075                         18.0
# 23368                                 4.075                         18.0
# 23785                                 4.075                         18.0
# 28680                                 4.075                         18.0
# 29387                                 4.075                         18.0
# 32252                                 4.075                         18.0
# 37419                                 4.075                         18.0
# 37439                                 4.075                         18.0
# 41908                                 4.075                         18.0
# 43487                                 4.075                         18.0
# 43611                                 4.075                         18.0
# 43737                                 4.075                         18.0
# 45873                                 4.075                         18.0
# 49015                                 4.075                         18.0
# 53615                                 4.075                         18.0
# 54575                                 4.075                         18.0
# 61437                                 4.075                         18.0
#
#        healthcare_within_2km_average_rating  recreational_within_1km_count  \
# 1589                               2.822222                            3.0
# 2377                               2.822222                            3.0
# 8411                               2.822222                            3.0
# 9872                               2.822222                            3.0
# 14003                              2.822222                            3.0
# 14528                              2.822222                            3.0
# 19148                              2.822222                            3.0
# 21785                              2.822222                            3.0
# 22966                              2.822222                            3.0
# 23368                              2.822222                            3.0
# 23785                              2.822222                            3.0
# 28680                              2.822222                            3.0
# 29387                              2.822222                            3.0
# 32252                              2.822222                            3.0
# 37419                              2.822222                            3.0
# 37439                              2.822222                            3.0
# 41908                              2.822222                            3.0
# 43487                              2.822222                            3.0
# 43611                              2.822222                            3.0
# 43737                              2.822222                            3.0
# 45873                              2.822222                            3.0
# 49015                              2.822222                            3.0
# 53615                              2.822222                            3.0
# 54575                              2.822222                            3.0
# 61437                              2.822222                            3.0
#
#        ...  storey_range_26 TO 30  storey_range_31 TO 35  \
# 1589   ...                  False                  False
# 2377   ...                  False                  False
# 8411   ...                  False                  False
# 9872   ...                  False                  False
# 14003  ...                  False                  False
# 14528  ...                  False                  False
# 19148  ...                  False                  False
# 21785  ...                  False                  False
# 22966  ...                  False                  False
# 23368  ...                  False                  False
# 23785  ...                  False                  False
# 28680  ...                  False                  False
# 29387  ...                  False                  False
# 32252  ...                  False                  False
# 37419  ...                  False                  False
# 37439  ...                  False                  False
# 41908  ...                  False                  False
# 43487  ...                  False                  False
# 43611  ...                  False                  False
# 43737  ...                  False                  False
# 45873  ...                  False                  False
# 49015  ...                  False                  False
# 53615  ...                  False                  False
# 54575  ...                  False                  False
# 61437  ...                  False                  False
#
#        storey_range_36 TO 40  storey_range_41 TO 50  region_Central  \
# 1589                   False                  False           False
# 2377                   False                  False           False
# 8411                   False                  False           False
# 9872                   False                  False           False
# 14003                  False                  False           False
# 14528                  False                  False           False
# 19148                  False                  False           False
# 21785                  False                  False           False
# 22966                  False                  False           False
# 23368                  False                  False           False
# 23785                  False                  False           False
# 28680                  False                  False           False
# 29387                  False                  False           False
# 32252                  False                  False           False
# 37419                  False                  False           False
# 37439                  False                  False           False
# 41908                  False                  False           False
# 43487                  False                  False           False
# 43611                  False                  False           False
# 43737                  False                  False           False
# 45873                  False                  False           False
# 49015                  False                  False           False
# 53615                  False                  False           False
# 54575                  False                  False           False
# 61437                  False                  False           False
#
#        region_City  region_East  region_North  region_South  region_West
# 1589         False         True         False         False        False
# 2377         False         True         False         False        False
# 8411         False         True         False         False        False
# 9872         False         True         False         False        False
# 14003        False         True         False         False        False
# 14528        False         True         False         False        False
# 19148        False         True         False         False        False
# 21785        False         True         False         False        False
# 22966        False         True         False         False        False
# 23368        False         True         False         False        False
# 23785        False         True         False         False        False
# 28680        False         True         False         False        False
# 29387        False         True         False         False        False
# 32252        False         True         False         False        False
# 37419        False         True         False         False        False
# 37439        False         True         False         False        False
# 41908        False         True         False         False        False
# 43487        False         True         False         False        False
# 43611        False         True         False         False        False
# 43737        False         True         False         False        False
# 45873        False         True         False         False        False
# 49015        False         True         False         False        False
# 53615        False         True         False         False        False
# 54575        False         True         False         False        False
# 61437        False         True         False         False        False
#
# [25 rows x 40 columns]

# %% [markdown]
# To further narrow down the choices for the target flat, we will now take other non-POI related attributes into consideration and identify flats that perform poorly in these aspects.

# %%
# Narrowing choices by looking at non-POI data
q3_floor_area = np.percentile(data_hdb_test_x['floor_area_sqm'], 75)
q2_remaining_lease = np.percentile(data_hdb_test_x['remaining_lease'], 50)
q1_nearest_distance_to_mrt = np.percentile(data_hdb_test_x['nearest_distance_to_mrt'], 25)

print("1st Quartile for Floor Area: ", q3_floor_area)
print("2nd Quartile for Remaining Lease: ", q2_remaining_lease)
print("3rd Quartile for Nearest Distance to Mrt:", q1_nearest_distance_to_mrt)
# Out:
# 1st Quartile for Floor Area:  113.0
# 2nd Quartile for Remaining Lease:  75.0
# 3rd Quartile for Nearest Distance to Mrt: 0.338

# %% [markdown]
# In considering the various non-POI related numerical attributes, the combination that provides us with the least number of choices (> 0) is as illustrated below.

# %%
# In contrast to how we selected the appropriate flats using POI-related attributes, here flats that rank poorly in terms of non POI-related attributes are selected
# This is to better highlight any impact that the amenities near a flat may have on its resale price
potential_cases2_x = potential_cases1_x[(potential_cases1_x.floor_area_sqm < q3_floor_area) & 
                                    (potential_cases1_x.remaining_lease < q2_remaining_lease) &
                                    (potential_cases1_x.nearest_distance_to_mrt < q1_nearest_distance_to_mrt)]

pd.set_option('display.max_columns', None)
potential_cases2_x

# %% [markdown]
# Out of the 3 remaining potential cases, the flat at index 43737 is chosen. This is because it while its location and flat type are the same as the other 2, it has the lowest storey range. Given that in Singapore, the general

# %%
selected_case_x = data_hdb_test_x[data_hdb_test_x.index == 43737]
selected_case_y = data_hdb_test_y[data_hdb_test_y.index == 43737]

# %%
# Retrieve from cleaned dataset
actual_price = selected_case_y.iloc[0,0]
actual_fas = selected_case_x.iloc[0,0]
actual_month = selected_case_x.iloc[0,1]

hdb_last15_cleaned_selected = hdb_last15_cleaned[(hdb_last15_cleaned.resale_price == actual_price) &
                                                 (hdb_last15_cleaned.floor_area_sqm == actual_fas) &
                                                 (hdb_last15_cleaned.month == actual_month)]

hdb_last15_cleaned_selected
# Out:
#             town flat_type flat_model  floor_area_sqm  resale_price  \
# 238602  TAMPINES    4 ROOM    Model A           105.0      530000.0
#
#              month  lease_commence_date storey_range block  remaining_lease  \
# 238602  2022-10-01                 1994     01 TO 05   390             70.5
#
#                    address                            full_address       lat  \
# 238602  390 TAMPINES AVE 7  390 TAMPINES AVENUE 7 SINGAPORE 520390  1.356182
#
#               long    nearest_mrt  nearest_distance_to_mrt   flat_category  \
# 238602  103.957616  tampines east                    0.331  4 ROOM Model A
#
#            street_name    avg_long   avg_lat  healthcare_within_1km_count  \
# 238602  TAMPINES AVE 7  103.956991  1.355567                          4.0
#
#         healthcare_within_1km_average_rating  healthcare_within_2km_count  \
# 238602                                 4.075                         18.0
#
#         healthcare_within_2km_average_rating  recreational_within_1km_count  \
# 238602                              2.822222                            3.0
#
#         recreational_within_1km_average_rating  recreational_within_2km_count  \
# 238602                                     4.1                           16.0
#
#         recreational_within_2km_average_rating  education_within_1km_count  \
# 238602                                  4.1375                         5.0
#
#         education_within_1km_average_rating  education_within_2km_count  \
# 238602                                 4.38                        16.0
#
#         education_within_2km_average_rating  postal_code region  price_per_sqm
# 238602                              4.28125     520390.0   East    5047.619048

# %%
latitude = hdb_last15_cleaned_selected.lat
longitude = hdb_last15_cleaned_selected.long

latitude
longitude
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 latitude = hdb_last15_cleaned_selected.lat
#       2 longitude = hdb_last15_cleaned_selected.long
#       4 latitude
#
# NameError: name 'hdb_last15_cleaned_selected' is not defined

# %% [markdown]
# ### Model Prediction

# %%
# Predictor Columns
predictor_cols = ['floor_area_sqm', 'remaining_lease', 'nearest_distance_to_mrt', 
                  'healthcare_within_1km_count', 'healthcare_within_1km_average_rating',
                  'healthcare_within_2km_count', 'healthcare_within_2km_average_rating', 
                  'recreational_within_1km_count', 'recreational_within_1km_average_rating', 
                  'recreational_within_2km_count', 'education_within_1km_count',
                  'education_within_1km_average_rating', 'education_within_2km_count',
                  'price_per_sqm', 'flat_type_3 ROOM', 'flat_type_4 ROOM',
                  'flat_type_5 ROOM', 'flat_type_EXECUTIVE', 'storey_range_01 TO 05',
                  'storey_range_06 TO 10', 'storey_range_10 TO 15', 'region_Central',
                  'region_East', 'region_North', 'region_South', 'region_West']

predictors = data_hdb_selected_x[predictor_cols]

# %%
# Predicted Value
predicted_price = price_model.predict(predictors)[0]
print("Predicted Resale Price:", predicted_price)

# Actual Value
print("Actual Resale Price:", actual_price)
# Out:
# Predicted Resale Price: 854790.0
# Actual Resale Price: 855000.0

# %% [markdown]
# From the Model's prediction, we can see that the predicted price differs from the actual price by only $210.

# %% [markdown]
# ### POIs Around HDB Flat

# %%
## Use Cells Here

# %% [markdown]
# ### HDB Flat Map

# %%
hdb_map = folium.Map(location = [latitude, longitude], zoom_start = 16)

# HDB Flat
popup_content_hdb = f"Predicted Price: {predicted_price}<br>Actual Price: {actual_price}"
folium.Marker(location = [latitude, longitude], 
              icon = folium.Icon(color = 'red'), 
              popup = folium.Popup(popup_content_hdb, max_width=500)).add_to(hdb_map)


# POIs Near HDB Flat
## Write Here 


hdb_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_135b8ec3ba014339018d47416dddc0c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_135b8ec3ba014339018d47416dddc0c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_135b8ec3ba014339018d47416dddc0c3 = L.map(
#                 &quot;map_135b8ec3ba014339018d47416dddc0c3&quot;,
#                 {
#                     center: [1.2957304268451, 103.809759937443],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b38b1cb6742e17c7338465e980e66ac6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b38b1cb6742e17c7338465e980e66ac6.addTo(map_135b8ec3ba014339018d47416dddc0c3);
#
#
#             var marker_bd915611e79684853649e728f4fbd2e9 = L.marker(
#                 [1.2957304268451, 103.809759937443],
#                 {}
#             ).addTo(map_135b8ec3ba014339018d47416dddc0c3);
#
#
#             var icon_dc658b6794b402e76fb18ee264a8766c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bd915611e79684853649e728f4fbd2e9.setIcon(icon_dc658b6794b402e76fb18ee264a8766c);
#
#
#         var popup_14bfd2df91cb9b99e8d3f774fa82854b = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_8223e941b8c2e90390220e61b294356e = $(`&lt;div id=&quot;html_8223e941b8c2e90390220e61b294356e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Predicted Price: 854790.0&lt;br&gt;Actual Price: 855000.0&lt;/div&gt;`)[0];
#                 popup_14bfd2df91cb9b99e8d3f774fa82854b.setContent(html_8223e941b8c2e90390220e61b294356e);
#
#
#
#         marker_bd915611e79684853649e728f4fbd2e9.bindPopup(popup_14bfd2df91cb9b99e8d3f774fa82854b)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Save Map

# %%
# Save the map to an HTML file
hdb_map.save('hdb_map.html')

# %% [markdown]
# ### Archive

# %%
# Placeholder Flat
# random_index = random.choice(data_hdb_test_x.index)
# print(random_index)

# data_hdb_selected_x = data_hdb_test_x[data_hdb_test_x.index == random_index]
# data_hdb_selected_y = data_hdb_test_y[data_hdb_test_y.index == random_index]
# Out:
# 14629

# %%
# data_hdb_selected_x

# %%
# data_hdb_selected_y
# Out:
#        resale_price
# 14629      855000.0

# %%
# Retrieve from Selected X Dataset
# actual_price = data_hdb_selected_y.iloc[0, 0]
# actual_fas =  data_hdb_selected_x.iloc[0, 0]
# actual_month = data_hdb_selected_x.iloc[0, 1]

# Retrieve from Merged Dataset
# hdb_last15_merged_selected = hdb_last15_merged[(hdb_last15_merged.resale_price == actual_price) & 
                                               # (hdb_last15_merged.floor_area_sqm == actual_fas) &
                                               # (hdb_last15_merged.month == actual_month)]
# hdb_last15_merged_selected
# Out:
#               town flat_type         flat_model  floor_area_sqm  resale_price  \
# 101195  QUEENSTOWN    4 ROOM  Premium Apartment            87.0      855000.0
#
#              month lease_commence_date storey_range block  remaining_lease  \
# 101195  2021-12-01          2016-01-01     16 TO 20    87            93.75
#
#         ... recreational_within_1km_count  \
# 101195  ...                           3.0
#
#        recreational_within_1km_average_rating  recreational_within_2km_count  \
# 101195                                    4.2                           12.0
#
#         recreational_within_2km_average_rating education_within_1km_count  \
# 101195                                4.041667                        4.0
#
#         education_within_1km_average_rating education_within_2km_count  \
# 101195                                 3.85                       12.0
#
#        education_within_2km_average_rating  postal_code  region
# 101195                            3.991667     141087.0   South
#
# [1 rows x 34 columns]
